# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_data=pd.read_csv("Frogs_MFCCs.csv")

# %%
print(df_data.shape)
# Out:
# (7195, 26)

# %%
df_data.head(26)
# Out:
#     MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0        1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1        1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2        1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3        1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4        1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# 5        1.0  0.099704 -0.033408  0.349895  0.344535  0.247569  0.022407
# 6        1.0  0.021676 -0.062075  0.318229  0.380439  0.179043 -0.041667
# 7        1.0  0.145130 -0.033660  0.284166  0.279537  0.175211  0.005791
# 8        1.0  0.271326  0.027777  0.375738  0.385432  0.272457  0.098192
# 9        1.0  0.120565 -0.107235  0.316555  0.364437  0.307757  0.025992
# 10       1.0  0.148539 -0.096910  0.257523  0.260881  0.312603  0.134134
# 11       1.0  0.277948  0.091657  0.331656  0.307372  0.257359  0.065702
# ...

# %%
df_data.isnull().sum()
# Out:
# MFCCs_ 1    0
# MFCCs_ 2    0
# MFCCs_ 3    0
# MFCCs_ 4    0
# MFCCs_ 5    0
# MFCCs_ 6    0
# MFCCs_ 7    0
# MFCCs_ 8    0
# MFCCs_ 9    0
# MFCCs_10    0
# MFCCs_11    0
# MFCCs_12    0
# MFCCs_13    0
# MFCCs_14    0
# MFCCs_15    0
# MFCCs_16    0
# MFCCs_17    0
# MFCCs_18    0
# MFCCs_19    0
# MFCCs_20    0
# MFCCs_21    0
# MFCCs_22    0
# Family      0
# Genus       0
# Species     0
# RecordID    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df_data.apply(LabelEncoder().fit_transform)   
df.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       248      1587       227       418      6667      6518      5634
# 1       248      1896       252      1017      6754      6570      5049
# 2       248      1577       291      1201      6377      5606      4376
# 3       248      2609      1604      1701      6883      6989      4452
# 4       248       741       342      1427      6732      6408      4361
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0       868       630      5535  ...       907      1097      4848      6313
# 1       296       517      6183  ...      1051      1486      4083      5842
# 2       217       482      6667  ...      1327      2277      3159      4527
# 3       457       880      6883  ...       623       139      1072      3611
# 4       142       620      6862  ...      1338      1559      2372      4305
#
#    MFCCs_21  MFCCs_22  Family  Genus  Species  RecordID
# ...

# %%
x = df.drop(['MFCCs_ 1'] , axis = 1)
y = df['MFCCs_ 1']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state = 0 , max_depth = 5)
dt.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %%
dt.score(x_train , y_train)
# Out:
# 0.9694201747418586

# %%
predictions = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , predictions)
# Out:
# 0.9629458082445577

# %%
from sklearn.tree import DecisionTreeClassifier
rf = DecisionTreeClassifier(max_depth = 5)

# %%
rf.fit(x_train , y_train)
rf.score(x_train , y_train)
# Out:
# 0.9694201747418586

# %%
predictions1 = rf.predict(x_test)
rf.score(x_test , y_test)
# Out:
# 0.9629458082445577

# %%
accuracy_score(y_test , predictions1)
# Out:
# 0.9629458082445577

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_data=pd.read_csv("Frogs_MFCCs.csv")

# %%
print(df_data.shape)
# Out:
# (7195, 26)

# %%
df_data.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
# ...

# %%
df_data.isnull().sum()
# Out:
# MFCCs_ 1    0
# MFCCs_ 2    0
# MFCCs_ 3    0
# MFCCs_ 4    0
# MFCCs_ 5    0
# MFCCs_ 6    0
# MFCCs_ 7    0
# MFCCs_ 8    0
# MFCCs_ 9    0
# MFCCs_10    0
# MFCCs_11    0
# MFCCs_12    0
# MFCCs_13    0
# MFCCs_14    0
# MFCCs_15    0
# MFCCs_16    0
# MFCCs_17    0
# MFCCs_18    0
# MFCCs_19    0
# MFCCs_20    0
# MFCCs_21    0
# MFCCs_22    0
# Family      0
# Genus       0
# Species     0
# RecordID    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df_data.apply(LabelEncoder().fit_transform)   
df.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       248      1587       227       418      6667      6518      5634
# 1       248      1896       252      1017      6754      6570      5049
# 2       248      1577       291      1201      6377      5606      4376
# 3       248      2609      1604      1701      6883      6989      4452
# 4       248       741       342      1427      6732      6408      4361
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0       868       630      5535  ...       907      1097      4848      6313
# 1       296       517      6183  ...      1051      1486      4083      5842
# 2       217       482      6667  ...      1327      2277      3159      4527
# 3       457       880      6883  ...       623       139      1072      3611
# 4       142       620      6862  ...      1338      1559      2372      4305
#
#    MFCCs_21  MFCCs_22  Family  Genus  Species  RecordID
# ...

# %%
x = df.drop(['MFCCs_ 1'] , axis = 1)
y = df['MFCCs_ 1']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
dt = RandomForestClassifier(random_state = 0 , max_depth = 5)
dt.fit(x_train , y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=0)

# %%
dt.score(x_train , y_train)
# Out:
# 0.9704130262112788

# %%
predictions = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , predictions)
# Out:
# 0.9629458082445577

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth = 5)

# %%
rf.fit(x_train , y_train)
rf.score(x_train , y_train)
# Out:
# 0.9698173153296267

# %%
predictions2 = rf.predict(x_test)
rf.score(x_test , y_test)
# Out:
# 0.9629458082445577

# %%
accuracy_score(y_test , predictions2)
# Out:
# 0.9629458082445577

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_data=pd.read_csv("Frogs_MFCCs.csv")

# %%
print(df_data.shape)
# Out:
# (7195, 26)

# %%
df_data.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
# ...

# %%
df_data.isnull().sum()
# Out:
# MFCCs_ 1    0
# MFCCs_ 2    0
# MFCCs_ 3    0
# MFCCs_ 4    0
# MFCCs_ 5    0
# MFCCs_ 6    0
# MFCCs_ 7    0
# MFCCs_ 8    0
# MFCCs_ 9    0
# MFCCs_10    0
# MFCCs_11    0
# MFCCs_12    0
# MFCCs_13    0
# MFCCs_14    0
# MFCCs_15    0
# MFCCs_16    0
# MFCCs_17    0
# MFCCs_18    0
# MFCCs_19    0
# MFCCs_20    0
# MFCCs_21    0
# MFCCs_22    0
# Family      0
# Genus       0
# Species     0
# RecordID    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df_data.apply(LabelEncoder().fit_transform)   
df.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       248      1587       227       418      6667      6518      5634
# 1       248      1896       252      1017      6754      6570      5049
# 2       248      1577       291      1201      6377      5606      4376
# 3       248      2609      1604      1701      6883      6989      4452
# 4       248       741       342      1427      6732      6408      4361
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0       868       630      5535  ...       907      1097      4848      6313
# 1       296       517      6183  ...      1051      1486      4083      5842
# 2       217       482      6667  ...      1327      2277      3159      4527
# 3       457       880      6883  ...       623       139      1072      3611
# 4       142       620      6862  ...      1338      1559      2372      4305
#
#    MFCCs_21  MFCCs_22  Family  Genus  Species  RecordID
# ...

# %%
x = df.drop(['MFCCs_ 1'] , axis = 1)
y = df['MFCCs_ 1']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0)
lr.fit(x_train, y_train)
# Out:
# C:\Users\aman\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
lr.score(x_train , y_train)
# Out:
# 1.0

# %%
predictions = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , predictions)
# Out:
# 0.9559981472904122

# %%
from  sklearn.linear_model import LogisticRegression
rf = LogisticRegression(random_state=0)

# %%
rf.fit(x_train , y_train)
rf.score(x_train , y_train)
# Out:
# C:\Users\aman\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 1.0

# %%
predictions3 = rf.predict(x_test)
rf.score(x_test , y_test)
# Out:
# 0.9559981472904122

# %%
accuracy_score(y_test , predictions3)
# Out:
# 0.9559981472904122

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_data=pd.read_csv("Frogs_MFCCs.csv")

# %%
print(df_data.shape)
# Out:
# (7195, 26)

# %%
df_data.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
# ...

# %%
df_data.isnull().sum()
# Out:
# MFCCs_ 1    0
# MFCCs_ 2    0
# MFCCs_ 3    0
# MFCCs_ 4    0
# MFCCs_ 5    0
# MFCCs_ 6    0
# MFCCs_ 7    0
# MFCCs_ 8    0
# MFCCs_ 9    0
# MFCCs_10    0
# MFCCs_11    0
# MFCCs_12    0
# MFCCs_13    0
# MFCCs_14    0
# MFCCs_15    0
# MFCCs_16    0
# MFCCs_17    0
# MFCCs_18    0
# MFCCs_19    0
# MFCCs_20    0
# MFCCs_21    0
# MFCCs_22    0
# Family      0
# Genus       0
# Species     0
# RecordID    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df_data.apply(LabelEncoder().fit_transform)   
df.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       248      1587       227       418      6667      6518      5634
# 1       248      1896       252      1017      6754      6570      5049
# 2       248      1577       291      1201      6377      5606      4376
# 3       248      2609      1604      1701      6883      6989      4452
# 4       248       741       342      1427      6732      6408      4361
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0       868       630      5535  ...       907      1097      4848      6313
# 1       296       517      6183  ...      1051      1486      4083      5842
# 2       217       482      6667  ...      1327      2277      3159      4527
# 3       457       880      6883  ...       623       139      1072      3611
# 4       142       620      6862  ...      1338      1559      2372      4305
#
#    MFCCs_21  MFCCs_22  Family  Genus  Species  RecordID
# ...

# %%
x = df.drop(['MFCCs_ 1'] , axis = 1)
y = df['MFCCs_ 1']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 0)

# %%
from sklearn import svm
svm_classifier = svm.SVC()
svm_classifier.fit(x_train, y_train)
# Out:
# SVC()

# %%
svm_classifier.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test ,y_pred)
# Out:
# 0.9629458082445577

# %%
from sklearn import svm
svm_classifier = svm.SVC()

# %%
svm_classifier.fit(x_train, y_train)
svm_classifier.score(x_train , y_train)
# Out:
# 0.9666401906274821

# %%
predictions4 = svm_classifier.predict(x_test)
svm_classifier.score(x_test , y_test)
# Out:
# 0.9629458082445577

# %%
accuracy_score(y_test , predictions4)
# Out:
# 0.9629458082445577

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df_data=pd.read_csv("Frogs_MFCCs.csv")

# %%
print(df_data.shape)
# Out:
# (7195, 26)

# %%
df_data.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
# ...

# %%
df_data.isnull().sum()
# Out:
# MFCCs_ 1    0
# MFCCs_ 2    0
# MFCCs_ 3    0
# MFCCs_ 4    0
# MFCCs_ 5    0
# MFCCs_ 6    0
# MFCCs_ 7    0
# MFCCs_ 8    0
# MFCCs_ 9    0
# MFCCs_10    0
# MFCCs_11    0
# MFCCs_12    0
# MFCCs_13    0
# MFCCs_14    0
# MFCCs_15    0
# MFCCs_16    0
# MFCCs_17    0
# MFCCs_18    0
# MFCCs_19    0
# MFCCs_20    0
# MFCCs_21    0
# MFCCs_22    0
# Family      0
# Genus       0
# Species     0
# RecordID    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df_data.apply(LabelEncoder().fit_transform)   
df.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       248      1587       227       418      6667      6518      5634
# 1       248      1896       252      1017      6754      6570      5049
# 2       248      1577       291      1201      6377      5606      4376
# 3       248      2609      1604      1701      6883      6989      4452
# 4       248       741       342      1427      6732      6408      4361
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0       868       630      5535  ...       907      1097      4848      6313
# 1       296       517      6183  ...      1051      1486      4083      5842
# 2       217       482      6667  ...      1327      2277      3159      4527
# 3       457       880      6883  ...       623       139      1072      3611
# 4       142       620      6862  ...      1338      1559      2372      4305
#
#    MFCCs_21  MFCCs_22  Family  Genus  Species  RecordID
# ...

# %%
x = df.drop(['MFCCs_ 1'] , axis = 1)
y = df['MFCCs_ 1']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3 , random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test ,y_pred)
# Out:
# 0.9615562760537286

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)

# %%
knn_classifier.fit(x_train, y_train)
knn_classifier.score(x_train, y_train)
# Out:
# 0.9733915806195393

# %%
predictions5 = knn_classifier.predict(x_test)
knn_classifier.score(x_test , y_test)
# Out:
# 0.9615562760537286

# %%
accuracy_score(y_test , predictions5)
# Out:
# 0.9615562760537286

# %%
final_data=pd.DataFrame({"Models":['DT','RF','LR','SVM','KNN'],
                        'PRE' :[accuracy_score(y_test , predictions1),
                               accuracy_score(y_test , predictions2),
                               accuracy_score(y_test , predictions3),
                               accuracy_score(y_test , predictions4),
                               accuracy_score(y_test , predictions5)]})

# %%
final_data
# Out:
#   Models       PRE
# 0     DT  0.962946
# 1     RF  0.962946
# 2     LR  0.955998
# 3    SVM  0.962946
# 4    KNN  0.961556

# %%
sns.barplot(final_data['Models'],final_data['PRE'])
# Out:
# C:\Users\aman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='Models', ylabel='PRE'>
